# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cars = pd.read_csv("Car details - Car details.csv")
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
cars.head(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6          Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 8                      Toyota Etios VXD  2011         350000      90000
# 9  Ford Figo Diesel Celebration Edition  2013         200000     169000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
# 5  Petrol  Individual       Manual   First Owner  20.14 kmpl  1197 CC
# 6     LPG  Individual       Manual   First Owner  17.3 km/kg  1061 CC
# 7  Petrol  Individual       Manual  Second Owner   16.1 kmpl   796 CC
# 8  Diesel  Individual       Manual   First Owner  23.59 kmpl  1364 CC
# 9  Diesel  Individual       Manual   First Owner   20.0 kmpl  1399 CC
#
#     max_power                    torque  seats
# 0      74 bhp            190Nm@ 2000rpm    5.0
# 1  103.52 bhp       250Nm@ 1500-2500rpm    5.0
# 2      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0
# 3      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 4    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0
# 5   81.86 bhp         113.75nm@ 4000rpm    5.0
# 6    57.5 bhp      7.8@ 4,500(kgm@ rpm)    5.0
# 7      37 bhp             59Nm@ 2500rpm    4.0
# 8    67.1 bhp       170Nm@ 1800-2400rpm    5.0
# 9    68.1 bhp            160Nm@ 2000rpm    5.0

# %%
cars.shape
# Out:
# (8128, 13)

# %%
cars.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
cars = cars.dropna(how = 'any')
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [7906 rows x 13 columns]

# %%
cars.shape
# Out:
# (7906, 13)

# %%
import re

# %%
res = '190Nm@ 2,000rpm'.replace(".", "")
res = res.replace(",", "")
a =  [int(s) for s in re.findall(r'\d+', res)]
a
# Out:
# [190, 2000]

# %%
torque_list = cars['torque'].to_list()
# torque_list[:2]
torque_rpm = []
def extractingRPM(x):
  for item in x:
    res = item.replace(".", "")
    res = res.replace(",", "")
    temp = [int(s) for s in re.findall(r'\d+', res)]
    torque_rpm.append(max(temp))

extractingRPM(torque_list)
print(torque_list[:2])
print(torque_rpm[:2])
# Out:
# ['190Nm@ 2000rpm', '250Nm@ 1500-2500rpm']
# [2000, 2500]

# %%
cars['torque_rpm'] = torque_rpm

cars.head(2)
# Out:
# <ipython-input-13-c85cf032f956>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['torque_rpm'] = torque_rpm
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats  torque_rpm
# 0       190Nm@ 2000rpm    5.0        2000
# 1  250Nm@ 1500-2500rpm    5.0        2500

# %%
mil_list = cars['mileage'].to_list()
# torque_list[:2]
mil_kmpl = []
def extractingmil(x):
  for item in x:
    temp = []
    try:
      for s in item.split(" "):
        temp.append(float(s))
    except:
      pass
    mil_kmpl.append(max(temp))

extractingmil(mil_list)
print(mil_list[:2])
print(mil_kmpl[:2])
# Out:
# ['23.4 kmpl', '21.14 kmpl']
# [23.4, 21.14]

# %%
cars['mil_kmpl'] = mil_kmpl

cars.head(2)
# Out:
# <ipython-input-15-e90946e722c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['mil_kmpl'] = mil_kmpl
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats  torque_rpm  mil_kmpl
# 0       190Nm@ 2000rpm    5.0        2000     23.40
# 1  250Nm@ 1500-2500rpm    5.0        2500     21.14

# %%
engine_list = cars['engine'].to_list()
# torque_list[:2]
engine_cc = []
def extractingEngine(x):
  for item in x:
    temp = []
    try:
      for s in item.split(" "):
        temp.append(float(s))
    except:
      pass
    engine_cc.append(max(temp))

extractingEngine(engine_list)
print(engine_list[:2])
print(engine_cc[:2])
# Out:
# ['1248 CC', '1498 CC']
# [1248.0, 1498.0]

# %%
cars['engine_cc'] = engine_cc

cars.head(2)
# Out:
# <ipython-input-17-49cf03898c76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['engine_cc'] = engine_cc
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats  torque_rpm  mil_kmpl  engine_cc
# 0       190Nm@ 2000rpm    5.0        2000     23.40     1248.0
# 1  250Nm@ 1500-2500rpm    5.0        2500     21.14     1498.0

# %%
power_list = cars['max_power'].to_list()
# torque_list[:2]
max_power = []
def extractingPower(x):
  for item in x:
    temp = []
    try:
      for s in item.split(" "):
        temp.append(float(s))
    except:
      pass
    max_power.append(max(temp))

extractingPower(power_list)
print(power_list[:2])
print(max_power[:2])
# Out:
# ['74 bhp', '103.52 bhp']
# [74.0, 103.52]

# %%
cars['max_power_new'] = max_power
cars['max_power_new']
# Out:
# <ipython-input-19-1c0ef20d3d13>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['max_power_new'] = max_power
# 0        74.00
# 1       103.52
# 2        78.00
# 3        90.00
# 4        88.20
#          ...
# 8123     82.85
# 8124    110.00
# 8125     73.90
# 8126     70.00
# 8127     70.00
# Name: max_power_new, Length: 7906, dtype: float64

# %%
cars.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats  torque_rpm  mil_kmpl  engine_cc  max_power_new
# 0       190Nm@ 2000rpm    5.0        2000     23.40     1248.0          74.00
# 1  250Nm@ 1500-2500rpm    5.0        2500     21.14     1498.0         103.52

# %%
cars_new = cars.drop(['mileage', 'engine', 'max_power', 'torque'], axis = 1)
cars_new
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner  seats  torque_rpm  \
# 0     Individual       Manual           First Owner    5.0        2000
# 1     Individual       Manual          Second Owner    5.0        2500
# 2     Individual       Manual           Third Owner    5.0        2700
# 3     Individual       Manual           First Owner    5.0        2750
# 4     Individual       Manual           First Owner    5.0        4500
# ...          ...          ...                   ...    ...         ...
# 8123  Individual       Manual           First Owner    5.0        4000
# 8124  Individual       Manual  Fourth & Above Owner    5.0        2750
# 8125  Individual       Manual           First Owner    5.0        2000
# 8126  Individual       Manual           First Owner    5.0        3000
# 8127  Individual       Manual           First Owner    5.0        3000
#
#       mil_kmpl  engine_cc  max_power_new
# 0        23.40     1248.0          74.00
# 1        21.14     1498.0         103.52
# 2        17.70     1497.0          78.00
# 3        23.00     1396.0          90.00
# 4        16.10     1298.0          88.20
# ...        ...        ...            ...
# 8123     18.50     1197.0          82.85
# 8124     16.80     1493.0         110.00
# 8125     19.30     1248.0          73.90
# 8126     23.57     1396.0          70.00
# 8127     23.57     1396.0          70.00
#
# [7906 rows x 13 columns]

# %%
cars_new.describe()
# Out:
#               year  selling_price     km_driven        seats    torque_rpm  \
# count  7906.000000   7.906000e+03  7.906000e+03  7906.000000   7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     5.416393   3474.631419
# std       3.863695   8.135827e+05  5.679230e+04     0.959208   2579.612132
# min    1994.000000   2.999900e+04  1.000000e+00     2.000000    400.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000   2500.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000   3000.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     5.000000   4000.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000  43639.000000
#
#           mil_kmpl    engine_cc  max_power_new
# count  7906.000000  7906.000000    7906.000000
# mean     19.419861  1458.708829      91.587374
# std       4.036263   503.893057      35.747216
# min       0.000000   624.000000      32.800000
# 25%      16.780000  1197.000000      68.050000
# 50%      19.300000  1248.000000      82.000000
# 75%      22.320000  1582.000000     102.000000
# max      42.000000  3604.000000     400.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(cars_new.corr(),annot=True,cmap='viridis',linewidths=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  We can see there is high correlation of selling price(which we will be predicting) with max_power output of the car
# # The values of correlation are pretty averaged out meaning we wont be excluding any clumn as each column is able to provide us with new
# # information that is not provided by any other column.

# %%
#finding categorical data
cars_new['fuel'].value_counts()
# Out:
# Diesel    4299
# Petrol    3520
# CNG         52
# LPG         35
# Name: fuel, dtype: int64

# %%
cars_new['seller_type'].value_counts()
# Out:
# Individual          6563
# Dealer              1107
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
cars_new['transmission'].value_counts()
# Out:
# Manual       6865
# Automatic    1041
# Name: transmission, dtype: int64

# %%
cars_new['owner'].value_counts()
# Out:
# First Owner             5215
# Second Owner            2016
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
# Converting categorical data to integer format.

def ref1(x):
  if x == 'Manual':
    return 1
  else:
    return 0

cars_new['transmission'] = cars_new['transmission'].map(ref1)

# %%
def ref2(x):
  if x == 'Individual':
    return 1
  elif x == 'Dealer':
    return 0
  else:
    return -1

cars_new['seller_type'] = cars_new['seller_type'].map(ref2)

# %%
def ref3(x):
  if x == 'Petrol':
    return 1
  elif x == 'Diesel':
    return 0
  else:
    return -1

cars_new['fuel'] = cars_new['fuel'].map(ref3)

# %%
owners = pd.get_dummies(cars_new['owner'])
owners
# Out:
#       First Owner  Fourth & Above Owner  Second Owner  Test Drive Car  \
# 0               1                     0             0               0
# 1               0                     0             1               0
# 2               0                     0             0               0
# 3               1                     0             0               0
# 4               1                     0             0               0
# ...           ...                   ...           ...             ...
# 8123            1                     0             0               0
# 8124            0                     1             0               0
# 8125            1                     0             0               0
# 8126            1                     0             0               0
# 8127            1                     0             0               0
#
#       Third Owner
# 0               0
# 1               0
# 2               1
# 3               0
# 4               0
# ...           ...
# 8123            0
# 8124            0
# 8125            0
# 8126            0
# 8127            0
#
# [7906 rows x 5 columns]

# %%
X = pd.concat([cars_new, owners], axis=1)
X
# Out:
#                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     0
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2         Honda City 2017-2020 EXi  2006         158000     140000     1
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4           Maruti Swift VXI BSIII  2007         130000     120000     1
# ...                            ...   ...            ...        ...   ...
# 8123             Hyundai i20 Magna  2013         320000     110000     1
# 8124         Hyundai Verna CRDi SX  2007         135000     119000     0
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000     0
# 8126               Tata Indigo CR4  2013         290000      25000     0
# 8127               Tata Indigo CR4  2013         290000      25000     0
#
#       seller_type  transmission                 owner  seats  torque_rpm  \
# 0               1             1           First Owner    5.0        2000
# 1               1             1          Second Owner    5.0        2500
# 2               1             1           Third Owner    5.0        2700
# 3               1             1           First Owner    5.0        2750
# 4               1             1           First Owner    5.0        4500
# ...           ...           ...                   ...    ...         ...
# 8123            1             1           First Owner    5.0        4000
# 8124            1             1  Fourth & Above Owner    5.0        2750
# 8125            1             1           First Owner    5.0        2000
# 8126            1             1           First Owner    5.0        3000
# 8127            1             1           First Owner    5.0        3000
#
#       mil_kmpl  engine_cc  max_power_new  First Owner  Fourth & Above Owner  \
# 0        23.40     1248.0          74.00            1                     0
# 1        21.14     1498.0         103.52            0                     0
# 2        17.70     1497.0          78.00            0                     0
# 3        23.00     1396.0          90.00            1                     0
# 4        16.10     1298.0          88.20            1                     0
# ...        ...        ...            ...          ...                   ...
# 8123     18.50     1197.0          82.85            1                     0
# 8124     16.80     1493.0         110.00            0                     1
# 8125     19.30     1248.0          73.90            1                     0
# 8126     23.57     1396.0          70.00            1                     0
# 8127     23.57     1396.0          70.00            1                     0
#
#       Second Owner  Test Drive Car  Third Owner
# 0                0               0            0
# 1                1               0            0
# 2                0               0            1
# 3                0               0            0
# 4                0               0            0
# ...            ...             ...          ...
# 8123             0               0            0
# 8124             0               0            0
# 8125             0               0            0
# 8126             0               0            0
# 8127             0               0            0
#
# [7906 rows x 18 columns]

# %%
X.head()
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     0
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2      Honda City 2017-2020 EXi  2006         158000     140000     1
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4        Maruti Swift VXI BSIII  2007         130000     120000     1
#
#    seller_type  transmission         owner  seats  torque_rpm  mil_kmpl  \
# 0            1             1   First Owner    5.0        2000     23.40
# 1            1             1  Second Owner    5.0        2500     21.14
# 2            1             1   Third Owner    5.0        2700     17.70
# 3            1             1   First Owner    5.0        2750     23.00
# 4            1             1   First Owner    5.0        4500     16.10
#
#    engine_cc  max_power_new  First Owner  Fourth & Above Owner  Second Owner  \
# 0     1248.0          74.00            1                     0             0
# 1     1498.0         103.52            0                     0             1
# 2     1497.0          78.00            0                     0             0
# 3     1396.0          90.00            1                     0             0
# 4     1298.0          88.20            1                     0             0
#
#    Test Drive Car  Third Owner
# 0               0            0
# 1               0            0
# 2               0            1
# 3               0            0
# 4               0            0

# %%
y = X['selling_price']
X = X.drop(['selling_price', 'name', 'owner'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'selling_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-3b570e2a948b> in <module>
# ----> 1 y = X['selling_price']
#       2 X = X.drop(['selling_price', 'name', 'owner'], axis = 1)
#
# ~\Desktop\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Desktop\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'selling_price'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X[:3000], y[:3000], test_size=0.2)
Xtrain, Xtest, ytrain, ytest
# Out:
# (      year  km_driven  fuel  seller_type  transmission  seats  torque_rpm  \
#  1093  2019       7032     1           -1             0    5.0        4800
#  2272  2010     380000     0            1             1    7.0        1500
#  455   2012     120000     0            1             1    5.0        2750
#  45    2018      32600     0            0             1    5.0        1750
#  593   2016      66693     1            0             1    5.0        4386
#  ...    ...        ...   ...          ...           ...    ...         ...
#  1686  2010      49000     1            1             1    5.0        4000
#  2191  2018      13887     1            1             1    5.0        4850
#  703   2008     120000     0            1             1    8.0        1500
#  567   2016      52000     0            1             1    5.0        1750
#  2638  2016      56494     1           -1             1    5.0        4800
#
#        mil_kmpl  engine_cc  max_power_new  First Owner  Fourth & Above Owner  \
#  1093     19.00     1199.0          88.76            1                     0
#  2272     13.60     2523.0          63.00            0                     0
#  455      22.54     1396.0          88.73            1                     0
#  45       24.30     1248.0          88.50            1                     0
#  593      25.17      799.0          53.30            1                     0
#  ...        ...        ...            ...          ...                   ...
#  1686     18.50     1197.0          80.00            1                     0
#  2191     17.00     1591.0         121.30            1                     0
#  703      13.60     2523.0          63.00            1                     0
#  567      23.65     1248.0          88.50            1                     0
#  2638     18.20     1199.0          88.70            1                     0
#
#        Second Owner  Test Drive Car  Third Owner
#  1093             0               0            0
#  2272             1               0            0
#  455              0               0            0
#  45               0               0            0
#  593              0               0            0
#  ...            ...             ...          ...
#  1686             0               0            0
#  2191             0               0            0
#  703              0               0            0
#  567              0               0            0
#  2638             0               0            0
#
#  [2400 rows x 15 columns],
#        year  km_driven  fuel  seller_type  transmission  seats  torque_rpm  \
#  2532  2014      39395     0            1             1    5.0        1750
#  1820  2013      80000     0            1             1    9.0        1500
#  1282  2006      60000     1            1             1    5.0        2000
#  2999  2005     300000     0            1             1    7.0        1500
#  1423  2012      90000     1            1             1    5.0        3500
#  ...    ...        ...   ...          ...           ...    ...         ...
#  1663  2007      99000     0            1             1    5.0        2000
#  2944  2013      70000     0            1             1    5.0        2000
#  1754  2011     116500     0            1             1    5.0        2750
#  3004  2010     100000     0            1             1    5.0        4500
#  1927  2015      45000     1            1             1    5.0        4000
#
#        mil_kmpl  engine_cc  max_power_new  First Owner  Fourth & Above Owner  \
#  2532     21.20     1248.0          75.00            1                     0
#  1820     15.96     2523.0          63.00            1                     0
#  1282     16.60     1388.0          68.00            0                     0
#  2999     13.60     2523.0          63.00            0                     0
#  1423     19.00      998.0          67.10            1                     0
#  ...        ...        ...            ...          ...                   ...
#  1663     19.20     1461.0          65.00            0                     0
#  2944     23.40     1248.0          74.00            0                     0
#  1754     23.00     1396.0          90.00            1                     0
#  3004     21.10     1248.0          73.90            1                     0
#  1927     20.85     1197.0          83.14            0                     0
#
#        Second Owner  Test Drive Car  Third Owner
#  2532             0               0            0
#  1820             0               0            0
#  1282             1               0            0
#  2999             0               0            1
#  1423             0               0            0
#  ...            ...             ...          ...
#  1663             1               0            0
#  2944             1               0            0
#  1754             0               0            0
#  3004             0               0            0
#  1927             1               0            0
#
#  [600 rows x 15 columns],
#  1093    779000
#  2272    260000
#  455     525000
#  45      819999
#  593     300000
#           ...
#  1686    300000
#  2191    950000
#  703     250000
#  567     675000
#  2638    550000
#  Name: selling_price, Length: 2400, dtype: int64,
#  2532    320000
#  1820    400000
#  1282    140000
#  2999    160000
#  1423    191000
#           ...
#  1663    175000
#  2944    356000
#  1754    350000
#  3004    220000
#  1927    515000
#  Name: selling_price, Length: 600, dtype: int64)

# %%
random_model = RandomForestRegressor(n_estimators=300, random_state = 42, n_jobs = -1)
random_model
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
#Fit
random_model.fit(Xtrain, ytrain)

y_pred = random_model.predict(Xtest)

#Checking the accuracy
random_model_accuracy = round(random_model.score(Xtrain, ytrain)*100,2)
print(round(random_model_accuracy, 2), '%')
# Out:
# 99.11 %

# %%
random_model_accuracy1 = round(random_model.score(Xtest, ytest)*100,2)
print(round(random_model_accuracy1, 2), '%')
# Out:
# 96.78 %

# %%
reg = LinearRegression()

reg.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(round(reg.score(Xtrain, ytrain), 2))
# Out:
# 0.69

# %%
print(round(reg.score(Xtest, ytest), 2))
# Out:
# 0.66

# %%
# Save the trained model as a pickle string.
import pickle 

saved_model = pickle.dump(random_model, open('drive/MyDrive/Dataset/Models/CarSelling.pickle','wb'))
saved_model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-77b6658fcf40> in <module>
#       2 import pickle
#       3
# ----> 4 saved_model = pickle.dump(random_model, open('drive/MyDrive/Dataset/Models/CarSelling.pickle','wb'))
#       5 saved_model
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/Dataset/Models/CarSelling.pickle'
